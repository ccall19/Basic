# %% [markdown]
# [官方文档](https://docs.python.org/zh-cn/3.10/library/intro.html#introduction)
#
# **本文目的**：对官方文档 笔记摘要以及 写一点点个人思考。

# %% [markdown]
# 本手册以 "从内到外" 的顺序组织：首先描述内置函数、数据类型和异常，最后是根据相关性进行分组的各种模块。
