# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Milvus 部署选项
# - Milvus Lite：Milvus 的轻量级版本
# - Milvus 单机版：是打包在 Docker 镜像中的单机服务器部署
# - 分布式 Milvus：通常需要使用 Kubernetes 集群
#
# ![image.png](attachment:image.png)
